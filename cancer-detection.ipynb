# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
        
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt


from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers.core import Dropout, Activation

from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
df_skin = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')

df_skin.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
df_skin.shape
# Out:
# (10015, 7)

# %%
# lesion names are given in the description of the dataset 
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

lesion_ID_dict = {
    'nv': 0,
    'mel': 1,
    'bkl': 2,
    'bcc': 3,
    'akiec': 4,
    'vasc': 5,
    'df': 6
}

lesion_names = ['Melanocytic nevi','Melanoma','Benign keratosis-like lesions ',
               'Basal cell carcinoma','Actinic keratoses','Vascular lesions',
               'Dermatofibroma']

lesion_names_short = ['nv','mel','bkl','bcc','akiec','vasc','df']

df_skin['lesion_type']=df_skin['dx'].map(lesion_type_dict)
df_skin['lesion_ID'] = df_skin['dx'].map(lesion_ID_dict)

print('Total number of images',len(df_skin))
print('The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels')

df_skin['lesion_type'].value_counts()
# Out:
# Total number of images 10015
# The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: lesion_type, dtype: int64

# %%
# read the first image
fname_images = np.array(df_skin['image_id'])
file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_images[0])+'.jpg'

import cv2
from cv2 import imread, resize

img = imread(file_to_read)
img2 = cv2.resize(img,(100,100))

# show one exampe image

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.title('Original image')
plt.subplot(1,2,2)
plt.imshow(img2[:,:,::-1])
plt.title('Resized image for DenseNet')
plt.show()

# %%
def produce_new_img(img2):
    # produce new images by rotating of flipping the original one
    # this helps to increase the dimension of the dataset, avoiding overfitting of a single class
    imga = cv2.rotate(img2,cv2.ROTATE_90_CLOCKWISE)
    imgb = cv2.rotate(img2,cv2.ROTATE_90_COUNTERCLOCKWISE)
    imgc = cv2.rotate(img2,cv2.ROTATE_180)
    imgd = cv2.flip(img2,0)
    imge = cv2.flip(img2,1)
    return imga,imgb,imgc,imgd,imge

new_img = produce_new_img(img2)

plt.figure(figsize=(10,8))
plt.subplot(2,3,1)
plt.imshow(img2[:,:,::-1])
for i in range(5):
    plt.subplot(2,3,2+i)
    plt.imshow(new_img[i][:,:,::-1])
plt.tight_layout()
plt.show()

# %%
X = []
y = []

lista1 = os.listdir('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/')
lista2 = os.listdir('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/')


#import images from folder 1
for i in range(len(lista1)):
    fname_image = lista1[i]
    fname_ID = fname_image.replace('.jpg','')
    
    #features 
    file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_image)
    img = imread(file_to_read)
    img2 = resize(img,(100,100))
    X.append(img2)
    
    #targets
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # add more images for class between 1-6, rotating them 
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            X.append(new_img[i])
            y.append(output[0])
       
    if i % int(100) == 0:
        print(i,'images loaded')

# import images from folder 2
for i in range(len(lista2)):
    fname_image = lista2[i]
    fname_ID = fname_image.replace('.jpg','')
    
    #features
    file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/'+str(fname_image)
    img = imread(file_to_read)
    img2 = resize(img,(100,100))
    X.append(img2)
    
    #targets
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])
    
    # add more images for class between 1-6
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            X.append(new_img[i])
            y.append(output[0])
    
    if i % int(100) == 0:

        print(len(lista1)+i,'images loaded')
# Out:
# 0 images loaded
# 100 images loaded
# 200 images loaded
# 300 images loaded
# 400 images loaded
# 500 images loaded
# 600 images loaded
# 700 images loaded
# 800 images loaded
# 1100 images loaded
# 1200 images loaded
# 1500 images loaded
# 1600 images loaded
# 1800 images loaded
# 2100 images loaded
# 2300 images loaded
# 2400 images loaded
# 2600 images loaded
# 2700 images loaded
# 2800 images loaded
# 2900 images loaded
# 3000 images loaded
# 3100 images loaded
# 3200 images loaded
# 3500 images loaded
# 3600 images loaded
# 3700 images loaded
# 3900 images loaded
# 4100 images loaded
# 4500 images loaded
# 4600 images loaded
# 4700 images loaded
# 4800 images loaded
# 4900 images loaded
# 5000 images loaded
# 5100 images loaded
# 5300 images loaded
# 5400 images loaded
# 5700 images loaded
# 5900 images loaded
# 6000 images loaded
# 6100 images loaded
# 6200 images loaded
# 6400 images loaded
# 6600 images loaded
# 6700 images loaded
# 6800 images loaded
# 6900 images loaded
# 7000 images loaded
# 7100 images loaded
# 7200 images loaded
# 7300 images loaded
# 7400 images loaded
# 7500 images loaded
# 7600 images loaded
# 7700 images loaded
# 7800 images loaded
# 8000 images loaded
# 8100 images loaded
# 8300 images loaded
# 8400 images loaded
# 8700 images loaded
# 8900 images loaded
# 9100 images loaded
# 9200 images loaded
# 9400 images loaded
# 9500 images loaded
# 9600 images loaded
# 9700 images loaded
# 9800 images loaded
# 9900 images loaded

# %%
from keras.utils.np_utils import to_categorical

X = np.array(X)
y = np.array(y)

y_train = to_categorical(y, num_classes=7)

# %%
from sklearn.model_selection import train_test_split

# split in 80% training and 20% test data
X_train, X_test, y_train, y_test = train_test_split(X, y_train, test_size=0.33, random_state=50,stratify=y)


print('Train dataset shape',X_train.shape)
print('Test dataset shape',X_test.shape)
# Out:
# Train dataset shape (17798, 100, 100, 3)
# Test dataset shape (8767, 100, 100, 3)

# %%
fig, ax = plt.subplots(1, 7, figsize=(30, 30))
for i in range(7):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(lesion_names[np.argmax(y_train[i])])

# %%
import keras
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers.core import Dropout, Activation
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Flatten,Dense

# %%
from sklearn.utils.class_weight import compute_class_weight
y_id = np.array(df_skin['lesion_ID'])

# compute weights for the loss function, because the problem is unbalanced
class_weights = np.around(compute_class_weight(class_weight='balanced',classes=np.unique(y_id),y=y),2)
class_weights = dict(zip(np.unique(y_id),class_weights))

print('The problem is unbalanced. We need to provide class_weights ')
print(class_weights)
# Out:
# The problem is unbalanced. We need to provide class_weights
# {0: 0.57, 1: 0.57, 2: 0.58, 3: 1.23, 4: 1.93, 5: 4.45, 6: 5.5}

# %%
# building Neural Network

import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Input, Activation, Dropout, GlobalAveragePooling2D, \
    BatchNormalization, concatenate, AveragePooling2D
from keras.optimizers import Adam

model = Sequential([
    
    # 1st convolutional layer
    Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(100,100,3)),
    BatchNormalization(),
    MaxPool2D(pool_size=(3,3), strides=(2,2)),
    
    # 2nd convolutional layer
    Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),
    MaxPool2D(pool_size=(3,3), strides=(2,2)),
    
    # 3rd convolutional layer
    Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),
    
    # 4th convolutional layer
    Conv2D(filters=384, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),
    
    # 5th convolutional layer
    Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),
    MaxPool2D(pool_size=(3,3), strides=(2,2)),
    
    Flatten(),
    
    # 6th, Dense layer
    Dense(4096, activation='relu'),
    Dropout(0.5),
    
    # 7th Dense layer
    Dense(4096, activation='relu'),
    Dropout(0.5),
    
    # 8th output layer
    Dense(7, activation='softmax')
])

# %%
# training
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

early_stopping_monitor = EarlyStopping(patience=100,monitor='val_accuracy')
model_checkpoint_callback = ModelCheckpoint(filepath='model.h5',
                                            save_weights_only=False,
                                            monitor='val_accuracy',
                                            mode='auto',
                                            save_best_only=True,
                                            verbose=1)
batch_size = 32
epochs = 100
optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-3)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics=['accuracy'])

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)

datagen.fit(X_train)

history=model.fit(datagen.flow(X_train,y_train), epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=[early_stopping_monitor,model_checkpoint_callback], validation_data=(X_test, y_test), class_weight=class_weights)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 557/557 [==============================] - ETA: 0s - loss: 1.7354 - accuracy: 0.4008
# Epoch 1: val_accuracy improved from -inf to 0.30307, saving model to model.h5
# 557/557 [==============================] - 51s 81ms/step - loss: 1.7354 - accuracy: 0.4008 - val_loss: 1.7486 - val_accuracy: 0.3031
# Epoch 2/100
# 557/557 [==============================] - ETA: 0s - loss: 1.3099 - accuracy: 0.4893
# Epoch 2: val_accuracy improved from 0.30307 to 0.31265, saving model to model.h5
# 557/557 [==============================] - 46s 83ms/step - loss: 1.3099 - accuracy: 0.4893 - val_loss: 1.8396 - val_accuracy: 0.3126
# Epoch 3/100
# 557/557 [==============================] - ETA: 0s - loss: 1.1592 - accuracy: 0.5342
# Epoch 3: val_accuracy improved from 0.31265 to 0.43379, saving model to model.h5
# 557/557 [==============================] - 44s 79ms/step - loss: 1.1592 - accuracy: 0.5342 - val_loss: 1.4908 - val_accuracy: 0.4338
# Epoch 4/100
# 557/557 [==============================] - ETA: 0s - loss: 1.0831 - accuracy: 0.5539
# Epoch 4: val_accuracy did not improve from 0.43379
# 557/557 [==============================] - 43s 77ms/step - loss: 1.0831 - accuracy: 0.5539 - val_loss: 1.5755 - val_accuracy: 0.3966
# Epoch 5/100
# 557/557 [==============================] - ETA: 0s - loss: 1.0248 - accuracy: 0.5751
# Epoch 5: val_accuracy did not improve from 0.43379
# 557/557 [==============================] - 43s 77ms/step - loss: 1.0248 - accuracy: 0.5751 - val_loss: 2.0039 - val_accuracy: 0.4020
# Epoch 6/100
# 557/557 [==============================] - ETA: 0s - loss: 1.0220 - accuracy: 0.5729
# Epoch 6: val_accuracy did not improve from 0.43379
# 557/557 [==============================] - 43s 77ms/step - loss: 1.0220 - accuracy: 0.5729 - val_loss: 1.3916 - val_accuracy: 0.4214
# Epoch 7/100
# 557/557 [==============================] - ETA: 0s - loss: 0.9615 - accuracy: 0.5863
# Epoch 7: val_accuracy improved from 0.43379 to 0.44428, saving model to model.h5
# 557/557 [==============================] - 45s 81ms/step - loss: 0.9615 - accuracy: 0.5863 - val_loss: 1.4428 - val_accuracy: 0.4443
# Epoch 8/100
# 557/557 [==============================] - ETA: 0s - loss: 0.8861 - accuracy: 0.6037
# Epoch 8: val_accuracy did not improve from 0.44428
# 557/557 [==============================] - 43s 78ms/step - loss: 0.8861 - accuracy: 0.6037 - val_loss: 2.0827 - val_accuracy: 0.3001
# Epoch 9/100
# 557/557 [==============================] - ETA: 0s - loss: 0.8721 - accuracy: 0.6097
# Epoch 9: val_accuracy improved from 0.44428 to 0.53416, saving model to model.h5
# 557/557 [==============================] - 44s 79ms/step - loss: 0.8721 - accuracy: 0.6097 - val_loss: 1.1813 - val_accuracy: 0.5342
# Epoch 10/100
# 557/557 [==============================] - ETA: 0s - loss: 0.7970 - accuracy: 0.6368
# Epoch 10: val_accuracy did not improve from 0.53416
# 557/557 [==============================] - 44s 79ms/step - loss: 0.7970 - accuracy: 0.6368 - val_loss: 2.0799 - val_accuracy: 0.4142
# Epoch 11/100
# 557/557 [==============================] - ETA: 0s - loss: 0.7963 - accuracy: 0.6392
# Epoch 11: val_accuracy did not improve from 0.53416
# 557/557 [==============================] - 43s 78ms/step - loss: 0.7963 - accuracy: 0.6392 - val_loss: 1.6575 - val_accuracy: 0.4542
# Epoch 12/100
# 557/557 [==============================] - ETA: 0s - loss: 0.7380 - accuracy: 0.6500
# Epoch 12: val_accuracy did not improve from 0.53416
# 557/557 [==============================] - 43s 78ms/step - loss: 0.7380 - accuracy: 0.6500 - val_loss: 1.3847 - val_accuracy: 0.4904
# Epoch 13/100
# 557/557 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.6654
# Epoch 13: val_accuracy improved from 0.53416 to 0.57545, saving model to model.h5
# 557/557 [==============================] - 44s 79ms/step - loss: 0.7049 - accuracy: 0.6654 - val_loss: 1.1267 - val_accuracy: 0.5755
# Epoch 14/100
# 557/557 [==============================] - ETA: 0s - loss: 0.7111 - accuracy: 0.6590
# Epoch 14: val_accuracy did not improve from 0.57545
# 557/557 [==============================] - 44s 78ms/step - loss: 0.7111 - accuracy: 0.6590 - val_loss: 3.5390 - val_accuracy: 0.2846
# Epoch 15/100
# 557/557 [==============================] - ETA: 0s - loss: 0.6639 - accuracy: 0.6784
# Epoch 15: val_accuracy did not improve from 0.57545
# 557/557 [==============================] - 44s 79ms/step - loss: 0.6639 - accuracy: 0.6784 - val_loss: 1.2220 - val_accuracy: 0.5320
# Epoch 16/100
# 557/557 [==============================] - ETA: 0s - loss: 0.6348 - accuracy: 0.6823
# Epoch 16: val_accuracy did not improve from 0.57545
# 557/557 [==============================] - 43s 77ms/step - loss: 0.6348 - accuracy: 0.6823 - val_loss: 1.3833 - val_accuracy: 0.5192
# Epoch 17/100
# 557/557 [==============================] - ETA: 0s - loss: 0.6264 - accuracy: 0.6883
# Epoch 17: val_accuracy did not improve from 0.57545
# 557/557 [==============================] - 44s 79ms/step - loss: 0.6264 - accuracy: 0.6883 - val_loss: 1.3518 - val_accuracy: 0.5242
# Epoch 18/100
# 557/557 [==============================] - ETA: 0s - loss: 0.5852 - accuracy: 0.7036
# Epoch 18: val_accuracy improved from 0.57545 to 0.62633, saving model to model.h5
# 557/557 [==============================] - 44s 79ms/step - loss: 0.5852 - accuracy: 0.7036 - val_loss: 1.0454 - val_accuracy: 0.6263
# Epoch 19/100
# 557/557 [==============================] - ETA: 0s - loss: 0.5543 - accuracy: 0.7067
# Epoch 19: val_accuracy did not improve from 0.62633
# 557/557 [==============================] - 44s 78ms/step - loss: 0.5543 - accuracy: 0.7067 - val_loss: 1.0914 - val_accuracy: 0.5910
# Epoch 20/100
# 557/557 [==============================] - ETA: 0s - loss: 0.5518 - accuracy: 0.7166
# Epoch 20: val_accuracy did not improve from 0.62633
# 557/557 [==============================] - 44s 78ms/step - loss: 0.5518 - accuracy: 0.7166 - val_loss: 1.7256 - val_accuracy: 0.4518
# Epoch 21/100
# 557/557 [==============================] - ETA: 0s - loss: 0.5168 - accuracy: 0.7272
# Epoch 21: val_accuracy did not improve from 0.62633
# 557/557 [==============================] - 44s 79ms/step - loss: 0.5168 - accuracy: 0.7272 - val_loss: 1.0878 - val_accuracy: 0.6041
# Epoch 22/100
# 557/557 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7249
# Epoch 22: val_accuracy did not improve from 0.62633
# 557/557 [==============================] - 43s 77ms/step - loss: 0.5197 - accuracy: 0.7249 - val_loss: 1.0665 - val_accuracy: 0.6221
# Epoch 23/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.7369
# Epoch 23: val_accuracy improved from 0.62633 to 0.68028, saving model to model.h5
# 557/557 [==============================] - 44s 80ms/step - loss: 0.4979 - accuracy: 0.7369 - val_loss: 0.8158 - val_accuracy: 0.6803
# Epoch 24/100
# 557/557 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.7386
# Epoch 24: val_accuracy did not improve from 0.68028
# 557/557 [==============================] - 43s 78ms/step - loss: 0.5034 - accuracy: 0.7386 - val_loss: 2.0307 - val_accuracy: 0.3587
# Epoch 25/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4896 - accuracy: 0.7410
# Epoch 25: val_accuracy improved from 0.68028 to 0.70492, saving model to model.h5
# 557/557 [==============================] - 45s 80ms/step - loss: 0.4896 - accuracy: 0.7410 - val_loss: 0.7478 - val_accuracy: 0.7049
# Epoch 26/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4725 - accuracy: 0.7468
# Epoch 26: val_accuracy improved from 0.70492 to 0.71701, saving model to model.h5
# 557/557 [==============================] - 45s 80ms/step - loss: 0.4725 - accuracy: 0.7468 - val_loss: 0.7329 - val_accuracy: 0.7170
# Epoch 27/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.7572
# Epoch 27: val_accuracy improved from 0.71701 to 0.74062, saving model to model.h5
# 557/557 [==============================] - 45s 81ms/step - loss: 0.4530 - accuracy: 0.7572 - val_loss: 0.6622 - val_accuracy: 0.7406
# Epoch 28/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.7709
# Epoch 28: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 44s 80ms/step - loss: 0.4195 - accuracy: 0.7709 - val_loss: 1.2675 - val_accuracy: 0.5952
# Epoch 29/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4186 - accuracy: 0.7708
# Epoch 29: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 43s 78ms/step - loss: 0.4186 - accuracy: 0.7708 - val_loss: 1.2964 - val_accuracy: 0.5985
# Epoch 30/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3990 - accuracy: 0.7828
# Epoch 30: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 45s 80ms/step - loss: 0.3990 - accuracy: 0.7828 - val_loss: 0.9609 - val_accuracy: 0.6253
# Epoch 31/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.7762
# Epoch 31: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 44s 79ms/step - loss: 0.4099 - accuracy: 0.7762 - val_loss: 0.8417 - val_accuracy: 0.6764
# Epoch 32/100
# 557/557 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.7785
# Epoch 32: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 45s 81ms/step - loss: 0.4100 - accuracy: 0.7785 - val_loss: 1.0805 - val_accuracy: 0.6592
# Epoch 33/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.7900
# Epoch 33: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 44s 79ms/step - loss: 0.3649 - accuracy: 0.7900 - val_loss: 1.2541 - val_accuracy: 0.5911
# Epoch 34/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.7937
# Epoch 34: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 45s 81ms/step - loss: 0.3710 - accuracy: 0.7937 - val_loss: 1.0047 - val_accuracy: 0.6406
# Epoch 35/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.7968
# Epoch 35: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 44s 78ms/step - loss: 0.3721 - accuracy: 0.7968 - val_loss: 0.7447 - val_accuracy: 0.7209
# Epoch 36/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.8032
# Epoch 36: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 46s 82ms/step - loss: 0.3498 - accuracy: 0.8032 - val_loss: 0.7441 - val_accuracy: 0.7258
# Epoch 37/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3417 - accuracy: 0.8062
# Epoch 37: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 44s 79ms/step - loss: 0.3417 - accuracy: 0.8062 - val_loss: 0.8877 - val_accuracy: 0.6897
# Epoch 38/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8167
# Epoch 38: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 44s 79ms/step - loss: 0.3188 - accuracy: 0.8167 - val_loss: 1.1367 - val_accuracy: 0.6166
# Epoch 39/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.8203
# Epoch 39: val_accuracy did not improve from 0.74062
# 557/557 [==============================] - 43s 77ms/step - loss: 0.3228 - accuracy: 0.8203 - val_loss: 1.1898 - val_accuracy: 0.5899
# Epoch 40/100
# 557/557 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.8145
# Epoch 40: val_accuracy improved from 0.74062 to 0.76366, saving model to model.h5
# 557/557 [==============================] - 44s 79ms/step - loss: 0.3320 - accuracy: 0.8145 - val_loss: 0.6143 - val_accuracy: 0.7637
# Epoch 41/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.8295
# Epoch 41: val_accuracy did not improve from 0.76366
# 557/557 [==============================] - 43s 78ms/step - loss: 0.2949 - accuracy: 0.8295 - val_loss: 0.6499 - val_accuracy: 0.7521
# Epoch 42/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.8327
# Epoch 42: val_accuracy did not improve from 0.76366
# 557/557 [==============================] - 43s 78ms/step - loss: 0.2948 - accuracy: 0.8327 - val_loss: 1.2248 - val_accuracy: 0.6456
# Epoch 43/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8365
# Epoch 43: val_accuracy improved from 0.76366 to 0.78624, saving model to model.h5
# 557/557 [==============================] - 43s 78ms/step - loss: 0.2859 - accuracy: 0.8365 - val_loss: 0.5548 - val_accuracy: 0.7862
# Epoch 44/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2893 - accuracy: 0.8335
# Epoch 44: val_accuracy improved from 0.78624 to 0.81100, saving model to model.h5
# 557/557 [==============================] - 43s 78ms/step - loss: 0.2893 - accuracy: 0.8335 - val_loss: 0.5130 - val_accuracy: 0.8110
# Epoch 45/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8467
# Epoch 45: val_accuracy did not improve from 0.81100
# 557/557 [==============================] - 43s 76ms/step - loss: 0.2683 - accuracy: 0.8467 - val_loss: 0.5342 - val_accuracy: 0.8053
# Epoch 46/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.8473
# Epoch 46: val_accuracy did not improve from 0.81100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2643 - accuracy: 0.8473 - val_loss: 1.1305 - val_accuracy: 0.6697
# Epoch 47/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.8521
# Epoch 47: val_accuracy did not improve from 0.81100
# 557/557 [==============================] - 43s 77ms/step - loss: 0.2533 - accuracy: 0.8521 - val_loss: 0.6046 - val_accuracy: 0.7801
# Epoch 48/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8434
# Epoch 48: val_accuracy did not improve from 0.81100
# 557/557 [==============================] - 44s 78ms/step - loss: 0.2832 - accuracy: 0.8434 - val_loss: 0.8021 - val_accuracy: 0.7275
# Epoch 49/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.8401
# Epoch 49: val_accuracy did not improve from 0.81100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2895 - accuracy: 0.8401 - val_loss: 0.5089 - val_accuracy: 0.8104
# Epoch 50/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.8570
# Epoch 50: val_accuracy did not improve from 0.81100
# 557/557 [==============================] - 45s 80ms/step - loss: 0.2490 - accuracy: 0.8570 - val_loss: 0.8251 - val_accuracy: 0.7297
# Epoch 51/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.8613
# Epoch 51: val_accuracy improved from 0.81100 to 0.81978, saving model to model.h5
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2398 - accuracy: 0.8613 - val_loss: 0.4939 - val_accuracy: 0.8198
# Epoch 52/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2559 - accuracy: 0.8605
# Epoch 52: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 80ms/step - loss: 0.2559 - accuracy: 0.8605 - val_loss: 1.5363 - val_accuracy: 0.5464
# Epoch 53/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.8553
# Epoch 53: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 42s 76ms/step - loss: 0.2577 - accuracy: 0.8553 - val_loss: 0.6870 - val_accuracy: 0.7632
# Epoch 54/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.8688
# Epoch 54: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2218 - accuracy: 0.8688 - val_loss: 0.5181 - val_accuracy: 0.8177
# Epoch 55/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2340 - accuracy: 0.8705
# Epoch 55: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 78ms/step - loss: 0.2340 - accuracy: 0.8705 - val_loss: 1.5934 - val_accuracy: 0.6213
# Epoch 56/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.8699
# Epoch 56: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2257 - accuracy: 0.8699 - val_loss: 1.4479 - val_accuracy: 0.6027
# Epoch 57/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.8752
# Epoch 57: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 45s 80ms/step - loss: 0.2217 - accuracy: 0.8752 - val_loss: 0.5379 - val_accuracy: 0.8057
# Epoch 58/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.8751
# Epoch 58: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2229 - accuracy: 0.8751 - val_loss: 0.8528 - val_accuracy: 0.7420
# Epoch 59/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.8844
# Epoch 59: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 78ms/step - loss: 0.1940 - accuracy: 0.8844 - val_loss: 0.5010 - val_accuracy: 0.8159
# Epoch 60/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.8881
# Epoch 60: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2028 - accuracy: 0.8881 - val_loss: 0.7592 - val_accuracy: 0.7508
# Epoch 61/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.8820
# Epoch 61: val_accuracy did not improve from 0.81978
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2100 - accuracy: 0.8820 - val_loss: 0.5946 - val_accuracy: 0.7867
# Epoch 62/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.8924
# Epoch 62: val_accuracy improved from 0.81978 to 0.83518, saving model to model.h5
# 557/557 [==============================] - 45s 80ms/step - loss: 0.1889 - accuracy: 0.8924 - val_loss: 0.4545 - val_accuracy: 0.8352
# Epoch 63/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1964 - accuracy: 0.8901
# Epoch 63: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 44s 79ms/step - loss: 0.1964 - accuracy: 0.8901 - val_loss: 0.5572 - val_accuracy: 0.8144
# Epoch 64/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.8978
# Epoch 64: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 44s 79ms/step - loss: 0.1735 - accuracy: 0.8978 - val_loss: 0.5919 - val_accuracy: 0.7995
# Epoch 65/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1830 - accuracy: 0.8944
# Epoch 65: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 44s 79ms/step - loss: 0.1830 - accuracy: 0.8944 - val_loss: 0.6372 - val_accuracy: 0.7942
# Epoch 66/100
# 557/557 [==============================] - ETA: 0s - loss: 0.2191 - accuracy: 0.8902
# Epoch 66: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 43s 78ms/step - loss: 0.2191 - accuracy: 0.8902 - val_loss: 1.9814 - val_accuracy: 0.5921
# Epoch 67/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.8886
# Epoch 67: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 43s 78ms/step - loss: 0.1982 - accuracy: 0.8886 - val_loss: 0.5072 - val_accuracy: 0.8248
# Epoch 68/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1833 - accuracy: 0.8941
# Epoch 68: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 44s 79ms/step - loss: 0.1833 - accuracy: 0.8941 - val_loss: 1.8812 - val_accuracy: 0.5678
# Epoch 69/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.8951
# Epoch 69: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 43s 77ms/step - loss: 0.1854 - accuracy: 0.8951 - val_loss: 1.3513 - val_accuracy: 0.6616
# Epoch 70/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9034
# Epoch 70: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1658 - accuracy: 0.9034 - val_loss: 0.6127 - val_accuracy: 0.7987
# Epoch 71/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9082
# Epoch 71: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1599 - accuracy: 0.9082 - val_loss: 0.4993 - val_accuracy: 0.8289
# Epoch 72/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9058
# Epoch 72: val_accuracy did not improve from 0.83518
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1658 - accuracy: 0.9058 - val_loss: 0.7243 - val_accuracy: 0.7713
# Epoch 73/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9088
# Epoch 73: val_accuracy improved from 0.83518 to 0.84373, saving model to model.h5
# 557/557 [==============================] - 43s 77ms/step - loss: 0.1695 - accuracy: 0.9088 - val_loss: 0.4461 - val_accuracy: 0.8437
# Epoch 74/100
# 556/557 [============================>.] - ETA: 0s - loss: 0.1554 - accuracy: 0.9104
# Epoch 74: val_accuracy improved from 0.84373 to 0.84898, saving model to model.h5
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1554 - accuracy: 0.9103 - val_loss: 0.4266 - val_accuracy: 0.8490
# Epoch 75/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9191
# Epoch 75: val_accuracy improved from 0.84898 to 0.85947, saving model to model.h5
# 557/557 [==============================] - 43s 77ms/step - loss: 0.1455 - accuracy: 0.9191 - val_loss: 0.4286 - val_accuracy: 0.8595
# Epoch 76/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9041
# Epoch 76: val_accuracy did not improve from 0.85947
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1726 - accuracy: 0.9041 - val_loss: 0.6578 - val_accuracy: 0.7872
# Epoch 77/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9135
# Epoch 77: val_accuracy did not improve from 0.85947
# 557/557 [==============================] - 43s 76ms/step - loss: 0.1600 - accuracy: 0.9135 - val_loss: 0.6057 - val_accuracy: 0.8064
# Epoch 78/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9127
# Epoch 78: val_accuracy improved from 0.85947 to 0.87886, saving model to model.h5
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1572 - accuracy: 0.9127 - val_loss: 0.4065 - val_accuracy: 0.8789
# Epoch 79/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9283
# Epoch 79: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1197 - accuracy: 0.9283 - val_loss: 0.7893 - val_accuracy: 0.7719
# Epoch 80/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9172
# Epoch 80: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 41s 74ms/step - loss: 0.1502 - accuracy: 0.9172 - val_loss: 0.4629 - val_accuracy: 0.8524
# Epoch 81/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9234
# Epoch 81: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1319 - accuracy: 0.9234 - val_loss: 0.9421 - val_accuracy: 0.7324
# Epoch 82/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9160
# Epoch 82: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 41s 74ms/step - loss: 0.1584 - accuracy: 0.9160 - val_loss: 0.4892 - val_accuracy: 0.8411
# Epoch 83/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9193
# Epoch 83: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 41s 74ms/step - loss: 0.1540 - accuracy: 0.9193 - val_loss: 0.4525 - val_accuracy: 0.8571
# Epoch 84/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9217
# Epoch 84: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1406 - accuracy: 0.9217 - val_loss: 0.4739 - val_accuracy: 0.8477
# Epoch 85/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9350
# Epoch 85: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1125 - accuracy: 0.9350 - val_loss: 0.4046 - val_accuracy: 0.8663
# Epoch 86/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9276
# Epoch 86: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1347 - accuracy: 0.9276 - val_loss: 1.4065 - val_accuracy: 0.6501
# Epoch 87/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9131
# Epoch 87: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1576 - accuracy: 0.9131 - val_loss: 1.0578 - val_accuracy: 0.7276
# Epoch 88/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9265
# Epoch 88: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 43s 78ms/step - loss: 0.1340 - accuracy: 0.9265 - val_loss: 1.1996 - val_accuracy: 0.6976
# Epoch 89/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9331
# Epoch 89: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 43s 77ms/step - loss: 0.1173 - accuracy: 0.9331 - val_loss: 0.7014 - val_accuracy: 0.7837
# Epoch 90/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9343
# Epoch 90: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 43s 77ms/step - loss: 0.1107 - accuracy: 0.9343 - val_loss: 1.3269 - val_accuracy: 0.6859
# Epoch 91/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9231
# Epoch 91: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 44s 79ms/step - loss: 0.1478 - accuracy: 0.9231 - val_loss: 1.1606 - val_accuracy: 0.6937
# Epoch 92/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9307
# Epoch 92: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1302 - accuracy: 0.9307 - val_loss: 0.4685 - val_accuracy: 0.8466
# Epoch 93/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9293
# Epoch 93: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 43s 77ms/step - loss: 0.1256 - accuracy: 0.9293 - val_loss: 0.5089 - val_accuracy: 0.8379
# Epoch 94/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9366
# Epoch 94: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1156 - accuracy: 0.9366 - val_loss: 1.1868 - val_accuracy: 0.7212
# Epoch 95/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9335
# Epoch 95: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1162 - accuracy: 0.9335 - val_loss: 0.4407 - val_accuracy: 0.8537
# Epoch 96/100
# 557/557 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9430
# Epoch 96: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.0997 - accuracy: 0.9430 - val_loss: 0.9109 - val_accuracy: 0.7544
# Epoch 97/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9390
# Epoch 97: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 75ms/step - loss: 0.1083 - accuracy: 0.9390 - val_loss: 0.4548 - val_accuracy: 0.8523
# Epoch 98/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9339
# Epoch 98: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1269 - accuracy: 0.9339 - val_loss: 2.1397 - val_accuracy: 0.5382
# Epoch 99/100
# 557/557 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9257
# Epoch 99: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 41s 74ms/step - loss: 0.1397 - accuracy: 0.9257 - val_loss: 0.6757 - val_accuracy: 0.7938
# Epoch 100/100
# 557/557 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9459
# Epoch 100: val_accuracy did not improve from 0.87886
# 557/557 [==============================] - 43s 77ms/step - loss: 0.0901 - accuracy: 0.9459 - val_loss: 0.5871 - val_accuracy: 0.8259

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 274/274 [==============================] - 1s 5ms/step - loss: 0.5871 - accuracy: 0.8259
# Accuracy: 82.59%

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(y_pred)):
    if np.argmax(y_pred[i]) == np.argmax(y_test[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)

print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# 274/274 [==============================] - 1s 3ms/step
# Total-test-data; 8767 	accurately-predicted-data: 7241 	 wrongly-predicted-data:  1526
# Accuracy: 82.594 %

# %%
best_model = load_model('model.h5')

# compute predictions
y_pred_prob = np.around(best_model.predict(X_test),3)
y_pred = np.argmax(y_pred_prob,axis=1)

y_test2 = np.argmax(y_test,axis=1)
# Out:
# 274/274 [==============================] - 1s 3ms/step

# %%
plt.figure(figsize=(16,16))
for i in range(16):
    plt.subplot(4,4,i+1)
    index = i+100
    plt.imshow(X_test[index,:,:,::-1])
    label_exp = lesion_names[y_test2[index]]  #expected label
    label_pred = lesion_names[y_pred[index]]  #predicted label
    label_pred_prob = round(np.max(y_pred_prob[index])*100)
    plt.title('Expected:'+str(label_exp)+'\n Pred.:'+str(label_pred)+' ('+str(label_pred_prob)+'%)')
plt.ylabel('')
plt.tight_layout()
plt.savefig('final_figure.png',dpi=300)
plt.show()

# %%
print('Accuracy for label equal to 0')
print(np.mean(y_test2[y_test2 == 0] == y_pred[y_test2 == 0]))

print('Accuracy for label different from 0')
print(np.mean(y_test2[y_test2 != 0] == y_pred[y_test2 != 0]))
# Out:
# Accuracy for label equal to 0
# 0.8043380027112517
# Accuracy for label different from 0
# 0.9038754958803784

# %%
acc_tot= []

for i in range(7):
    acc_parz = round(np.mean(y_test2[y_test2 == i] == y_pred[y_test2 == i]),2)
    lab_parz = lesion_names[i]
    print('accuracy for',lab_parz,'=',acc_parz)
    acc_tot.append(acc_parz)
# Out:
# accuracy for Melanocytic nevi = 0.8
# accuracy for Melanoma = 0.92
# accuracy for Benign keratosis-like lesions  = 0.87
# accuracy for Basal cell carcinoma = 0.92
# accuracy for Actinic keratoses = 0.87
# accuracy for Vascular lesions = 0.99
# accuracy for Dermatofibroma = 0.96
